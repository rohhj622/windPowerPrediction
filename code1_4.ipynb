# %% [markdown]
# <a href="https://colab.research.google.com/github/rohhj622/windPowerPrediction/blob/master/code1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 데이터 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
from datetime import datetime

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn import model_selection
from keras import models, layers, Sequential
from keras.layers import LSTM, Dropout, Dense, Activation, Input, SimpleRNN

# %% [markdown]
# ## 1) 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## 3) 데이터 불러오기 시작

# %%
allData = pd.read_csv(r'/content/gdrive/My Drive/Colab Notebooks/preprocessing_Data.csv') # 컬럼명 숫자로 들어가게
allData = allData.drop('Unnamed: 0',1)
allData
# Out:
#                   datetime                 date  ... seaLevelPressure  groundTem
# 0      2013-01-01 00:00:00  2013-01-01 00:00:00  ...           1021.3        0.0
# 1      2013-01-01 01:00:00  2013-01-01 00:00:00  ...           1021.2        0.0
# 2      2013-01-01 02:00:00  2013-01-01 00:00:00  ...           1021.2        0.0
# 3      2013-01-01 03:00:00  2013-01-01 00:00:00  ...           1021.2        0.3
# 4      2013-01-01 04:00:00  2013-01-01 00:00:00  ...           1020.8        0.1
# ...                    ...                  ...  ...              ...        ...
# 52579  2018-12-31 19:00:00  2018-12-31 00:00:00  ...           1034.7        3.3
# 52580  2018-12-31 20:00:00  2018-12-31 00:00:00  ...           1034.6        2.9
# 52581  2018-12-31 21:00:00  2018-12-31 00:00:00  ...           1034.5        1.9
# 52582  2018-12-31 22:00:00  2018-12-31 00:00:00  ...           1034.2        2.1
# 52583  2018-12-31 23:00:00  2018-12-31 00:00:00  ...           1034.6        1.6
#
# [52584 rows x 13 columns]

# %% [markdown]
# # 2. 데이터 가공하기

# %% [markdown]
# ## 1) datetime 컬럼 제작, datetime 형식으로 변환

# %%
df = allData.copy()
df['datetime'] = pd.to_datetime(df['datetime'],format='%Y-%m-%d %H:%M', errors='ignore') #합친거 datetime 형식으로 변환
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d', errors='ignore')  #date형식으로 변환
#df['time'] = pd.to_datetime(df['time'],format='%H:%M', errors='ignore') #time 형식으로 변환
df.head(5)
# Out:
#              datetime       date   time  ...  pressure  seaLevelPressure  groundTem
# 0 2013-01-01 00:00:00 2013-01-01  00:00  ...    1019.1            1021.3        0.0
# 1 2013-01-01 01:00:00 2013-01-01  01:00  ...    1019.0            1021.2        0.0
# 2 2013-01-01 02:00:00 2013-01-01  02:00  ...    1019.0            1021.2        0.0
# 3 2013-01-01 03:00:00 2013-01-01  03:00  ...    1019.0            1021.2        0.3
# 4 2013-01-01 04:00:00 2013-01-01  04:00  ...    1018.5            1020.8        0.1
#
# [5 rows x 13 columns]

# %% [markdown]
# ## 2) 년(year), 월(month), 일(day), 계절(season) 컬럼 생성

# %%
df['year'] = df['date'].dt.year # 년
df['month'] = df['date'].dt.month # 월
df['day'] = df['date'].dt.day# 일

conditionlist = [
    (df['month'] == 3)|(df['month'] == 4)| (df['month'] == 5) ,
    (df['month'] == 6)|(df['month'] == 7)|(df['month'] == 8) ,
    (df['month'] == 9)|(df['month'] == 10)|(df['month'] == 11),
    (df['month'] == 12)|(df['month'] == 1)|(df['month'] == 2) ]
choicelist = ['0', '1', '2','3']
#choicelist = ['spring', 'summer', 'autumn','winter']
df['season'] = np.select(conditionlist, choicelist, default='Not Specified')
df.head(5)
# Out:
#              datetime       date   time  windForce  ...  year  month  day  season
# 0 2013-01-01 00:00:00 2013-01-01  00:00          0  ...  2013      1    1       3
# 1 2013-01-01 01:00:00 2013-01-01  01:00          0  ...  2013      1    1       3
# 2 2013-01-01 02:00:00 2013-01-01  02:00         92  ...  2013      1    1       3
# 3 2013-01-01 03:00:00 2013-01-01  03:00        269  ...  2013      1    1       3
# 4 2013-01-01 04:00:00 2013-01-01  04:00        541  ...  2013      1    1       3
#
# [5 rows x 17 columns]

# %% [markdown]
# # 4. 훈련 & 예측

# %% [markdown]
# ## 1) train-test data 나누기

# %%
df2 = df.copy()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52584 entries, 0 to 52583
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          52584 non-null  datetime64[ns]
#  1   date              52584 non-null  datetime64[ns]
#  2   time              52584 non-null  object
#  3   windForce         52584 non-null  int64
#  4   tem               52584 non-null  float64
#  5   windSpeed         52584 non-null  float64
#  6   windDirect        52584 non-null  int64
#  7   humidity          52584 non-null  float64
#  8   vaporPressure     52584 non-null  float64
#  9   dewPoint          52584 non-null  float64
#  10  pressure          52584 non-null  float64
#  11  seaLevelPressure  52584 non-null  float64
#  12  groundTem         52584 non-null  float64
#  13  year              52584 non-null  int64
#  14  month             52584 non-null  int64
#  15  day               52584 non-null  int64
#  16  season            52584 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(5), object(2)
# memory usage: 6.8+ MB

# %%
X = df2[['tem','windSpeed','windDirect','humidity']] #,'groundTem','seaLevelPressure'
y = df2[['windForce']]

transform = MinMaxScaler()
trans_X=transform.fit_transform(X)
trans_y=transform.fit_transform(y)

X_train, X_test,y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)
print('train data 개수 : ', len(X_train))
print('test data 개수: ', len(X_test))
print(len(X_train)+len(X_test))
# Out:
# train data 개수 :  42067
# test data 개수:  10517
# 52584

# %%
X_train.ndim
X_train.shape
# Out:
# (42067, 4)

# %% [markdown]
# ## 5. MakeDataSet

# %%
# https://teddylee777.github.io/tensorflow/LSTM%EC%9C%BC%EB%A1%9C-%EC%98%88%EC%B8%A1%ED%95%B4%EB%B3%B4%EB%8A%94-%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90-%EC%A3%BC%EA%B0%80
def make_dataset(data, label, window_size=1):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
# X = df2[['tem','windSpeed','humidity','groundTem','windDirect','seaLevelPressure']] #,'windDirect'
# X = df2[['tem','windSpeed','groundTem']] #,'windDirect'
transform = MinMaxScaler()

scale_cols=['tem','windSpeed','groundTem','windForce']
df_scaled = df2[['tem','windSpeed','groundTem','windForce']] 
df_scaled = transform.fit_transform(df_scaled)
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

train = df_scaled[:int(len(df2)*0.8)]
test = df_scaled[int(len(df2)*0.8):]
print(train.head())
print(test.head())
# Out:
#         tem  windSpeed  groundTem  windForce
# 0  0.190123   0.180791   0.061135   0.000000
# 1  0.180247   0.146893   0.061135   0.000000
# 2  0.195062   0.169492   0.061135   0.007663
# 3  0.224691   0.096045   0.065502   0.022407
# 4  0.172840   0.101695   0.062591   0.045065
#             tem  windSpeed  groundTem  windForce
# 42067  0.607407   0.158192   0.312955   0.144940
# 42068  0.585185   0.062147   0.305677   0.111370
# 42069  0.565432   0.067797   0.298399   0.079967
# 42070  0.558025   0.073446   0.292576   0.061808
# 42071  0.562963   0.079096   0.289665   0.055560

# %%
WINDOW_SIZE = 1 # 일 데이터를 묶을지 (window_size : 20, 1)
feature1 = ['tem','windSpeed','groundTem','windForce']
labels1 = ['windForce']

train_feature = train[feature1]
train_label = train[labels1]

train_feature, train_label = make_dataset(train_feature, train_label, WINDOW_SIZE)

X_train, X_valid,y_train, y_valid = train_test_split(train_feature,train_label,test_size=0.2,random_state=10) # train, valid
print(X_train.shape, X_valid.shape)
# Out:
# (33652, 1, 4) (8414, 1, 4)

# %%
test_feature = test[feature1]
test_label = test[labels1]
test_feature, test_label = make_dataset(test_feature, test_label, WINDOW_SIZE)
test_feature.shape, test_label.shape
# Out:
# ((10516, 1, 4), (10516, 1))

# %% [markdown]
# ### model loss function

# %%
from sklearn.metrics import mean_squared_error
def RMSE(y_test1, y_predict):
    return np.sqrt(mean_squared_error(y_test1, y_predict))

def MSE(y_test1, y_predict):
    return mean_squared_error(y_test1, y_predict)

# %% [markdown]
# ### nn model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
import os

# %%
nn_model = Sequential()
nn_model.add(Dense(128, input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu'))
nn_model.add(Dense(64, activation='relu'))
nn_model.add(Dense(32, activation='relu'))
nn_model.add(Dense(16, activation='relu'))
nn_model.add(Dense(1, activation='sigmoid'))

# %%
nn_model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model_path = '/content/gdrive/My Drive/Colab Notebooks'
filename = os.path.join(model_path, 'tmp_nn_model1.h5')
print(filename)
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = nn_model.fit(X_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(X_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])
# Out:
# /content/gdrive/My Drive/Colab Notebooks/tmp_nn_model1.h5
# Epoch 1/200
# 2104/2104 [==============================] - 5s 2ms/step - loss: 0.0163 - mae: 0.0860 - acc: 0.1193 - val_loss: 0.0094 - val_mae: 0.0618 - val_acc: 0.1192
#
# Epoch 00001: val_loss improved from inf to 0.00942, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_nn_model1.h5
# Epoch 2/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0090 - mae: 0.0617 - acc: 0.1194 - val_loss: 0.0090 - val_mae: 0.0605 - val_acc: 0.1192
#
# Epoch 00002: val_loss improved from 0.00942 to 0.00899, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_nn_model1.h5
# Epoch 3/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0090 - mae: 0.0614 - acc: 0.1215 - val_loss: 0.0093 - val_mae: 0.0624 - val_acc: 0.1192
#
# Epoch 00003: val_loss did not improve from 0.00899
# Epoch 4/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0092 - mae: 0.0615 - acc: 0.1211 - val_loss: 0.0088 - val_mae: 0.0603 - val_acc: 0.1192
#
# Epoch 00004: val_loss improved from 0.00899 to 0.00884, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_nn_model1.h5
# Epoch 5/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0088 - mae: 0.0603 - acc: 0.1237 - val_loss: 0.0089 - val_mae: 0.0609 - val_acc: 0.1192
#
# Epoch 00005: val_loss did not improve from 0.00884
# Epoch 6/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0090 - mae: 0.0610 - acc: 0.1202 - val_loss: 0.0090 - val_mae: 0.0620 - val_acc: 0.1192
#
# Epoch 00006: val_loss did not improve from 0.00884
# Epoch 7/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0091 - mae: 0.0610 - acc: 0.1219 - val_loss: 0.0090 - val_mae: 0.0610 - val_acc: 0.1192
#
# Epoch 00007: val_loss did not improve from 0.00884
# Epoch 8/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0088 - mae: 0.0605 - acc: 0.1211 - val_loss: 0.0090 - val_mae: 0.0587 - val_acc: 0.1192
#
# Epoch 00008: val_loss did not improve from 0.00884
# Epoch 9/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0088 - mae: 0.0599 - acc: 0.1204 - val_loss: 0.0087 - val_mae: 0.0595 - val_acc: 0.1192
#
# Epoch 00009: val_loss improved from 0.00884 to 0.00875, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_nn_model1.h5
# Epoch 10/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0088 - mae: 0.0595 - acc: 0.1192 - val_loss: 0.0088 - val_mae: 0.0584 - val_acc: 0.1192
#
# Epoch 00010: val_loss did not improve from 0.00875
# Epoch 11/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0091 - mae: 0.0609 - acc: 0.1193 - val_loss: 0.0088 - val_mae: 0.0620 - val_acc: 0.1192
#
# Epoch 00011: val_loss did not improve from 0.00875
# Epoch 12/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0090 - mae: 0.0608 - acc: 0.1184 - val_loss: 0.0090 - val_mae: 0.0613 - val_acc: 0.1192
#
# Epoch 00012: val_loss did not improve from 0.00875
# Epoch 13/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0088 - mae: 0.0595 - acc: 0.1208 - val_loss: 0.0089 - val_mae: 0.0613 - val_acc: 0.1192
#
# Epoch 00013: val_loss did not improve from 0.00875
# Epoch 14/200
# 2104/2104 [==============================] - 4s 2ms/step - loss: 0.0088 - mae: 0.0599 - acc: 0.1178 - val_loss: 0.0088 - val_mae: 0.0601 - val_acc: 0.1192
#
# Epoch 00014: val_loss did not improve from 0.00875

# %%
# weight 로딩
nn_model.load_weights(filename)

# 예측
nn_pred = nn_model.predict(test_feature)

# %%
print(nn_pred[1][0])
# Out:
# [0.13000602]

# %%
nn_pred2 = nn_pred.copy()

# %%
def make2D(arr1):
  res_arr = []
  for i in range(0,len(arr1)):
    res_arr.append(arr1[i][0])
  return res_arr

# %%
plt.figure(figsize=(16,10))
ax1 = sns.distplot(test_label,hist=False,label='y')
ax2 = sns.distplot(nn_pred,hist=False,label='y_hat',ax=ax1)

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
print(MSE(test_label, make2D(nn_pred2)))
#print(RMSE(test_label, pred))
loss, acc, dfd = nn_model.evaluate(X_train, y_train)
loss
# Out:
# 0.009200271365639464
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0592 - acc: 0.1212
# 0.008653039112687111

# %% [markdown]
# ### lstm model

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(128,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=False))
lstm_model.add(Dense(64, activation='relu'))
lstm_model.add(Dense(32, activation='relu'))
lstm_model.add(Dense(16, activation='relu'))
lstm_model.add(Dense(1, activation='sigmoid'))

# network.add(layers.Dense(128, input_shape=train_feature.shape,activation='relu'))
# network.add(layers.Dense(64,activation='relu'))
# network.add(layers.Dense(1))

# %%
lstm_model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model_path = '/content/gdrive/My Drive/Colab Notebooks'
filename = os.path.join(model_path, 'tmp_lstm1.h5')
print(filename)
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = lstm_model.fit(X_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(X_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])
# Out:
# /content/gdrive/My Drive/Colab Notebooks/tmp_lstm1.h5
# Epoch 1/200
# 2104/2104 [==============================] - 9s 3ms/step - loss: 0.0238 - mae: 0.1032 - acc: 0.1196 - val_loss: 0.0091 - val_mae: 0.0622 - val_acc: 0.1192
#
# Epoch 00001: val_loss improved from inf to 0.00913, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_lstm1.h5
# Epoch 2/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0092 - mae: 0.0632 - acc: 0.1208 - val_loss: 0.0093 - val_mae: 0.0632 - val_acc: 0.1192
#
# Epoch 00002: val_loss did not improve from 0.00913
# Epoch 3/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0093 - mae: 0.0625 - acc: 0.1203 - val_loss: 0.0090 - val_mae: 0.0619 - val_acc: 0.1192
#
# Epoch 00003: val_loss improved from 0.00913 to 0.00904, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_lstm1.h5
# Epoch 4/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0090 - mae: 0.0611 - acc: 0.1207 - val_loss: 0.0089 - val_mae: 0.0602 - val_acc: 0.1192
#
# Epoch 00004: val_loss improved from 0.00904 to 0.00887, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_lstm1.h5
# Epoch 5/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0089 - mae: 0.0612 - acc: 0.1217 - val_loss: 0.0090 - val_mae: 0.0603 - val_acc: 0.1192
#
# Epoch 00005: val_loss did not improve from 0.00887
# Epoch 6/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0092 - mae: 0.0617 - acc: 0.1197 - val_loss: 0.0089 - val_mae: 0.0594 - val_acc: 0.1192
#
# Epoch 00006: val_loss did not improve from 0.00887
# Epoch 7/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0091 - mae: 0.0611 - acc: 0.1238 - val_loss: 0.0092 - val_mae: 0.0614 - val_acc: 0.1192
#
# Epoch 00007: val_loss did not improve from 0.00887
# Epoch 8/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0089 - mae: 0.0605 - acc: 0.1227 - val_loss: 0.0089 - val_mae: 0.0595 - val_acc: 0.1192
#
# Epoch 00008: val_loss did not improve from 0.00887
# Epoch 9/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0090 - mae: 0.0608 - acc: 0.1233 - val_loss: 0.0088 - val_mae: 0.0599 - val_acc: 0.1192
#
# Epoch 00009: val_loss improved from 0.00887 to 0.00880, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_lstm1.h5
# Epoch 10/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0089 - mae: 0.0607 - acc: 0.1193 - val_loss: 0.0088 - val_mae: 0.0594 - val_acc: 0.1192
#
# Epoch 00010: val_loss did not improve from 0.00880
# Epoch 11/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0089 - mae: 0.0610 - acc: 0.1178 - val_loss: 0.0089 - val_mae: 0.0592 - val_acc: 0.1192
#
# Epoch 00011: val_loss did not improve from 0.00880
# Epoch 12/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0088 - mae: 0.0608 - acc: 0.1225 - val_loss: 0.0088 - val_mae: 0.0601 - val_acc: 0.1192
#
# Epoch 00012: val_loss did not improve from 0.00880
# Epoch 13/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0090 - mae: 0.0604 - acc: 0.1190 - val_loss: 0.0088 - val_mae: 0.0595 - val_acc: 0.1192
#
# Epoch 00013: val_loss improved from 0.00880 to 0.00876, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_lstm1.h5
# Epoch 14/200
# 2104/2104 [==============================] - 7s 3ms/step - loss: 0.0087 - mae: 0.0602 - acc: 0.1208 - val_loss: 0.0088 - val_mae: 0.0597 - val_acc: 0.1192
#
# Epoch 00014: val_loss did not improve from 0.00876
# Epoch 15/200
# 2104/2104 [==============================] - 8s 4ms/step - loss: 0.0087 - mae: 0.0597 - acc: 0.1212 - val_loss: 0.0089 - val_mae: 0.0585 - val_acc: 0.1192
#
# Epoch 00015: val_loss did not improve from 0.00876
# Epoch 16/200
# 2104/2104 [==============================] - 8s 4ms/step - loss: 0.0086 - mae: 0.0594 - acc: 0.1242 - val_loss: 0.0089 - val_mae: 0.0633 - val_acc: 0.1192
#
# Epoch 00016: val_loss did not improve from 0.00876
# Epoch 17/200
# 2104/2104 [==============================] - 8s 4ms/step - loss: 0.0089 - mae: 0.0603 - acc: 0.1238 - val_loss: 0.0088 - val_mae: 0.0599 - val_acc: 0.1192
#
# Epoch 00017: val_loss did not improve from 0.00876
# Epoch 18/200
# 2104/2104 [==============================] - 8s 4ms/step - loss: 0.0086 - mae: 0.0596 - acc: 0.1224 - val_loss: 0.0089 - val_mae: 0.0628 - val_acc: 0.1192
#
# Epoch 00018: val_loss did not improve from 0.00876

# %%
# weight 로딩
lstm_model.load_weights(filename)

# 예측
pred = lstm_model.predict(test_feature)

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,10))
ax1 = sns.distplot(test_label,hist=False,label='y')
ax2 = sns.distplot(pred,hist=False,label='y_hat',ax=ax1)

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
print(MSE(test_label, pred)) 
print(RMSE(test_label, pred))
print(lstm_model.evaluate(X_train, y_train))
# Out:
# 0.00918461570191127
# 0.0958364007145055
# 1052/1052 [==============================] - 2s 1ms/step - loss: 0.0087 - mae: 0.0592 - acc: 0.1212
# [0.008656889200210571, 0.05922200158238411, 0.1212112233042717]

# %% [markdown]
# ### RNN

# %%
rnn_model = Sequential()
rnn_model.add(SimpleRNN(128,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=False))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dense(32, activation='relu'))
rnn_model.add(Dense(16, activation='relu'))
rnn_model.add(Dense(1, activation='sigmoid'))

# network.add(layers.Dense(128, input_shape=train_feature.shape,activation='relu'))
# network.add(layers.Dense(64,activation='relu'))
# network.add(layers.Dense(1))

# %%
rnn_model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model_path = '/content/gdrive/My Drive/Colab Notebooks'
filename = os.path.join(model_path, 'tmp_rnn1.h5')
print(filename)
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = rnn_model.fit(X_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(X_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])
# Out:
# /content/gdrive/My Drive/Colab Notebooks/tmp_rnn1.h5
# Epoch 1/200
# 2104/2104 [==============================] - 6s 3ms/step - loss: 0.0170 - mae: 0.0872 - acc: 0.1202 - val_loss: 0.0091 - val_mae: 0.0642 - val_acc: 0.1192
#
# Epoch 00001: val_loss improved from inf to 0.00913, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_rnn1.h5
# Epoch 2/200
# 2104/2104 [==============================] - 5s 2ms/step - loss: 0.0090 - mae: 0.0625 - acc: 0.1227 - val_loss: 0.0088 - val_mae: 0.0603 - val_acc: 0.1192
#
# Epoch 00002: val_loss improved from 0.00913 to 0.00882, saving model to /content/gdrive/My Drive/Colab Notebooks/tmp_rnn1.h5
# Epoch 3/200
# 2104/2104 [==============================] - 5s 3ms/step - loss: 0.0093 - mae: 0.0628 - acc: 0.1193 - val_loss: 0.0102 - val_mae: 0.0675 - val_acc: 0.1192
#
# Epoch 00003: val_loss did not improve from 0.00882
# Epoch 4/200
# 2104/2104 [==============================] - 5s 2ms/step - loss: 0.0092 - mae: 0.0619 - acc: 0.1227 - val_loss: 0.0099 - val_mae: 0.0640 - val_acc: 0.1192
#
# Epoch 00004: val_loss did not improve from 0.00882
# Epoch 5/200
# 2104/2104 [==============================] - 5s 2ms/step - loss: 0.0093 - mae: 0.0614 - acc: 0.1196 - val_loss: 0.0090 - val_mae: 0.0619 - val_acc: 0.1192
#
# Epoch 00005: val_loss did not improve from 0.00882
# Epoch 6/200
# 2104/2104 [==============================] - 5s 2ms/step - loss: 0.0092 - mae: 0.0613 - acc: 0.1219 - val_loss: 0.0093 - val_mae: 0.0624 - val_acc: 0.1192
#
# Epoch 00006: val_loss did not improve from 0.00882
# Epoch 7/200
# 2104/2104 [==============================] - 5s 2ms/step - loss: 0.0090 - mae: 0.0606 - acc: 0.1228 - val_loss: 0.0088 - val_mae: 0.0614 - val_acc: 0.1192
#
# Epoch 00007: val_loss did not improve from 0.00882

# %%
# weight 로딩
rnn_model.load_weights(filename)

# 예측
rnn_pred = rnn_model.predict(test_feature)

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(rnn_pred, label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,10))
ax1 = sns.distplot(test_label,hist=False,label='y')
ax2 = sns.distplot(rnn_pred,hist=False,label='y_hat',ax=ax1)

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
print(MSE(test_label, rnn_pred)) 
print(RMSE(test_label, rnn_pred))
print(rnn_model.evaluate(X_train, y_train))
# Out:
# 0.009244175592326632
# 0.0961466358866842
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]

# %% [markdown]
# ### RNN + LSTM

# %%
rnn_lstm_model = Sequential()
rnn_lstm_model.add(SimpleRNN(128,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=True))
rnn_lstm_model.add(LSTM(128,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=False))
rnn_lstm_model.add(Dense(64, activation='relu'))
rnn_lstm_model.add(Dense(32, activation='relu'))
rnn_lstm_model.add(Dense(16, activation='relu'))
rnn_lstm_model.add(Dense(1, activation='sigmoid'))

# %%
rnn_lstm_model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model_path = '/content/gdrive/My Drive/Colab Notebooks'
filename = os.path.join(model_path, 'tmp_rnn_lstm1.h5')
print(filename)
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = rnn_lstm_model.fit(X_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(X_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])

# %%
# weight 로딩
rnn_lstm_model.load_weights(filename)

# 예측
rnn_lstm_pred = rnn_lstm_model.predict(test_feature)

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(rnn_pred, label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,10))
ax1 = sns.distplot(test_label,hist=False,label='y')
ax2 = sns.distplot(rnn_pred,hist=False,label='y_hat',ax=ax1)
plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
print(MSE(test_label, rnn_lstm_pred)) 
print(RMSE(test_label, rnn_lstm_pred))
print(rnn_model.evaluate(X_train, y_train))
# Out:
# 0.009266432612368274
# 0.09626231148465257
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]

# %%
## 
print('----------------NN-----------------')
print(MSE(test_label, make2D(nn_pred)))
print(RMSE(test_label, pred))
print(nn_model.evaluate(X_train, y_train))
print('\n----------------LSTM-----------------')
print(MSE(test_label, pred)) 
print(RMSE(test_label, pred))
print(lstm_model.evaluate(X_train, y_train))
print('\n----------------RNN-----------------')
print(MSE(test_label, rnn_pred)) 
print(RMSE(test_label, rnn_pred))
print(rnn_model.evaluate(X_train, y_train))
print('\n----------------RNN+LSTM-----------------')
print(MSE(test_label, rnn_lstm_pred)) 
print(RMSE(test_label, rnn_lstm_pred))
print(rnn_model.evaluate(X_train, y_train))
# Out:
# ----------------NN-----------------
# 0.009200271365639464
# 0.0958364007145055
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0592 - acc: 0.1212
# [0.008653039112687111, 0.05922709405422211, 0.1212112233042717]
#
# ----------------LSTM-----------------
# 0.00918461570191127
# 0.0958364007145055
# 1052/1052 [==============================] - 2s 2ms/step - loss: 0.0087 - mae: 0.0592 - acc: 0.1212
# [0.008656889200210571, 0.05922200158238411, 0.1212112233042717]
#
# ----------------RNN-----------------
# 0.009244175592326632
# 0.0961466358866842
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]
#
# ----------------RNN+LSTM-----------------
# 0.009266432612368274
# 0.09626231148465257
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]

# %% [markdown]
# ### RNN + LSTM1

# %%
rnn_lstm1_model = Sequential()
rnn_lstm1_model.add(SimpleRNN(128,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=True))
rnn_lstm1_model.add(LSTM(64,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=True))
rnn_lstm1_model.add(LSTM(64,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=True))
rnn_lstm1_model.add(LSTM(32,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=True))
rnn_lstm1_model.add(LSTM(16,input_shape=(train_feature.shape[1], train_feature.shape[2]), activation='relu', return_sequences=False))
rnn_lstm1_model.add(Dense(1, activation='sigmoid'))

# %%
rnn_lstm1_model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae', 'acc'])
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model_path = '/content/gdrive/My Drive/Colab Notebooks'
filename = os.path.join(model_path, 'tmp_rnn_lstm2.h5')
print(filename)
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = rnn_lstm1_model.fit(X_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(X_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])

# %%
# weight 로딩
rnn_lstm1_model.load_weights(filename)

# 예측
rnn_lstm1_pred = rnn_lstm1_model.predict(test_feature)

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(rnn_lstm1_pred, label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,10))
ax1 = sns.distplot(test_label,hist=False,label='y')
ax2 = sns.distplot(rnn_lstm1_pred,hist=False,label='y_hat',ax=ax1)
plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
## 
print('----------------NN-----------------')
print(MSE(test_label, make2D(nn_pred)))
print(RMSE(test_label, pred))
print(nn_model.evaluate(X_train, y_train))
print('\n----------------LSTM-----------------')
print(MSE(test_label, pred)) 
print(RMSE(test_label, pred))
print(lstm_model.evaluate(X_train, y_train))
print('\n----------------RNN-----------------')
print(MSE(test_label, rnn_pred)) 
print(RMSE(test_label, rnn_pred))
print(rnn_model.evaluate(X_train, y_train))
print('\n----------------RNN+LSTM-----------------')
print(MSE(test_label, rnn_lstm_pred)) 
print(RMSE(test_label, rnn_lstm_pred))
print(rnn_model.evaluate(X_train, y_train))
print('\n----------------RNN+LSTM2-----------------')
print(MSE(test_label, rnn_lstm1_pred)) 
print(RMSE(test_label, rnn_lstm1_pred))
print(rnn_model.evaluate(X_train, y_train))
# Out:
# ----------------NN-----------------
# 0.009200271365639464
# 0.0958364007145055
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0592 - acc: 0.1212
# [0.008653039112687111, 0.05922709405422211, 0.1212112233042717]
#
# ----------------LSTM-----------------
# 0.00918461570191127
# 0.0958364007145055
# 1052/1052 [==============================] - 2s 1ms/step - loss: 0.0087 - mae: 0.0592 - acc: 0.1212
# [0.008656889200210571, 0.05922200158238411, 0.1212112233042717]
#
# ----------------RNN-----------------
# 0.009244175592326632
# 0.0961466358866842
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]
#
# ----------------RNN+LSTM-----------------
# 0.009266432612368274
# 0.09626231148465257
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]
#
# ----------------RNN+LSTM2-----------------
# 0.009177034411848209
# 0.09579683925813111
# 1052/1052 [==============================] - 1s 1ms/step - loss: 0.0087 - mae: 0.0601 - acc: 0.1212
# [0.008711792528629303, 0.060060180723667145, 0.1212112233042717]
